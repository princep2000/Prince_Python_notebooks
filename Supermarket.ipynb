# %%
stationary={
            'pen':{'brand':{'link':{'price':[5,10],'stock':[200,100]},
                            'fine':{'price':[5,10],'stock':[250,150]}
                           }
                  },
            'register':{'brand':{'classmate':{'price':[50,80],'stock':[100,50]},
                            'icon':{'price':[50,60],'stock':[200,80]}
                           }
                      },
            'books':{'class VI':{'price':500,'stock':20},
                     'class VII':{'price':600,'stock':20},
                     'class VIII':{'price':700,'stock':20},
                     'class IX':{'price':800,'stock':20},
                     'class X':{'price':900,'stock':20},
                    }
}

electronics={
            'mobile':{'brand':{'one plus':{'model':['7 pro','8 pro','7'],'price':[40000,46000,35000],'stock':[20,20,10]},
                              'iphone':{'model':['6','10','11'],'price':[20000,56000,100000],'stock':[20,20,10]},
                              'MI':{'model':['10 pro','8 pro','8A','7 pro','6A'],'price':[40000,15000,9000,10000,8000],'stock':[20,50,50,30,100]}
                             }
                  },
            'laptop':{'brand':{'hp':{'model':['HP Pavilion Gaming 15','HP Omen 15','HP Spectre x360 (2019)'],'price':[55000,95000,150000],'stock':[5,5,5]},
                              'samsung':{'model':['Samsung ChromeBook XE50','Samsung ChromeBook 3 XE501C13-K01US','Samsung Spin 7 NP730QAA'],'price':[25000,46000,90000],'stock':[20,20,10]},
                              'dell':{'model':['Dell Inspiron Core','Dell Inspiron Touchscreen 15 5548 Notebook','Dell Vostro 3458'],'price':[25000,75000,29000],'stock':[15,10,20]}
                             }
                  }
}



cosmatic={
            'bodylotion':{'brand':{'joy':{'price':[50,100],'stock':[100,50]},
                                   'vaseline':{'price':[120,200],'stock':[120,100]}
                           }
                  },
            'soap':{'brand':{'lifeboy':{'price':[10,20],'stock':[100,50]},
                            'dettol':{'price':[20,40],'stock':[200,80]},
                            'godrej no.1 ':{'price':[15,25],'stock':[200,80]},
                           }
                },
            'cream':{'brand':{'boroplus':{'price':[20,40],'stock':[100,50]},
                            'fair Handsome':{'price':[20,40],'stock':[200,80]},
                            'meglow':{'price':[50,100],'stock':[200,80]},
                           }
                   },
            'perfume':{'brand':{'denver':{'price':[100,200],'stock':[100,50]},
                            'park avenue':{'price':[120,180],'stock':[200,80]},
                            'fogg':{'price':[150,195],'stock':[200,80]},
                           }
                   }
}



chocolate={
            'dairymilk':{'price':[20,40,60,80,100],'stock':[100,90,80,70,60]},
            'munch':{'price':[5,10,20,40,60],'stock':[100,90,80,70,60]},
            'kit-kat':{'price':[5,10,20,40,60],'stock':[100,90,80,70,60]},
            'five star':{'price':[5,10,20,40],'stock':[100,80,70,60]},
    'perk':{'price':[5,10,20,40],'stock':[100,90,80,70]}
}
import shelve
db=shelve.open('supermarket.db',writeback=True)
db['stationary']=stationary
db['electronics']=electronics
db['cosmetics']=cosmatic
db['chocolate']=chocolate
db.close()
import time
import os
l=['Catagory\tProduct\tBrand\tQuantity\tRs./Qt.\tTotal']
def main():
    s='''1.Stationary\n2.Electronics\n3.Cosmetics\n4.Chocolate\n5.Exit'''
    print(s)
    ch=int(input('Enter a number: '))
    if ch==1:
        stationary()
    elif ch==2:
        electronics()
    elif ch==3:
        cosmetics()
    elif ch==4:
        chocolate()
    else:
        exit()
        
def exit():
    l1=list()
    for i in l:
        l1.append(i.split('\t'))

    for i in l1:
        for j in i:
            print(f"{j :>15}",end='\t')

        print()
        print('_'*100)
    sum1=0
    for j in l1[1:]:
        sum1+=int(j[-1])

    print('Grand Total: ',f'{sum1}'.rjust(81,' '))
    
    
    print('Thanks for using our service')
    for i in '..........Exciting..........':
        time.sleep(0.05)
        print(i,end='')

def stationary():
    db=shelve.open('supermarket.db',writeback=True)
    count=1
    for i in db['stationary']:
        print(f"{count}.{i}")
        count+=1
    print(f"{count}.main")
    ch=int(input('Select Item from Above: '))
    if ch==1:
        s='''\n1.Link\n2.Fine'''
        print(s)
        ch=int(input('select brand: '))
        if ch==1:
            print('Avaialable Prices: ',db['stationary']['pen']['brand']['link']['price'])
            price=int(input('Please select Price from Above'))
            try:
                index1=db['stationary']['pen']['brand']['link']['price'].index(price)
                qt=int(input('Enter the quantity: '))
                db['stationary']['pen']['brand']['link']['stock'][index1]-=qt
                l.append(f'Stationary\tPen\tLink\t{qt}\t{price}\t{qt*price}')
                db.close()
                print(f'You select {qt} quantity of Pen')
                stationary()
            except:
                print('Please select valid input')
                stationary()
        
        elif ch==2:
            print('Avaialable Prices: ',db['stationary']['pen']['brand']['fine']['price'])
            price=int(input('Please select Price from Above'))
            try:
                index1=db['stationary']['pen']['brand']['fine']['price'].index(price)
                qt=int(input('Enter the quantity: '))
                db['stationary']['pen']['brand']['fine']['stock'][index1]-=qt
                l.append(f'Stationary\tPen\tFine\t{qt}\t{price}\t{qt*price}')
                db.close()
                print(f'You select {qt} quantity of Pen')
                stationary()
            except:
                print('Please select valid input')
                stationary()
                
        else:
            print('Please select valid input')
            stationary()
    
    
    
    elif ch==2:
        s='''\n1.Classmate\n2.Icon'''
        print(s)
        ch=int(input('select brand: '))
        if ch==1:
            print('Avaialable Prices: ',db['stationary']['register']['brand']['classmate']['price'])
            price=int(input('Please select Price from Above'))
            try:
                index1=db['stationary']['register']['brand']['classmate']['price'].index(price)
                qt=int(input('Enter the quantity: '))
                db['stationary']['register']['brand']['classmate']['stock'][index1]-=qt
                l.append(f'Stationary\tRegister\tFine\t{qt}\t{price}\t{qt*price}')
                db.close()
                print(f'You select {qt} quantity of register')
                stationary()
            except:
                print('Please select valid input')
                stationary()
        
        elif ch==2:
            print('Avaialable Prices: ',db['stationary']['register']['brand']['icon']['price'])
            price=int(input('Please select Price from Above'))
            try:
                index1=db['stationary']['register']['brand']['icon']['price'].index(price)
                qt=int(input('Enter the quantity: '))
                db['stationary']['register']['brand']['icon']['stock'][index1]-=qt
                l.append(f'Stationary\tRegister\tIcon\t{qt}\t{price}\t{qt*price}')
                db.close()
                print(f'You select {qt} quantity of register')
                stationary()
            except:
                print('Please select valid input')
                stationary()
                
        else:
            print('Please select valid input')
            stationary()
    
    elif ch==3:
        count=1
        for i in db['stationary']['books']:
            print(f"{count}.{i}")
            count+=1
        print(f"{count}.main")
        ch=int(input('Enter the class From Above: '))
        if ch==1:
            price=db['stationary']['books']['class VI']['price']
            qt=int(input('How many sets you required: '))
            db['stationary']['books']['class VI']['stock']-=qt
            print(f'You purchase {qt} quantity of book')
            l.append(f'Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}')
            db.close()
            stationary()
        elif ch==2:
            price=db['stationary']['books']['class VII']['price']
            qt=int(input('How many sets you required: '))
            db['stationary']['books']['class VII']['stock']-=qt
            print(f'You purchase {qt} quantity of book')
            l.append(f'Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}')
            db.close()
            stationary()
        elif ch==3:
            price=db['stationary']['books']['class VIII']['price']
            qt=int(input('How many sets you required: '))
            db['stationary']['books']['class VIII']['stock']-=qt
            print(f'You purchase {qt} quantity of book')
            l.append(f'Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}')
            db.close()
            stationary()
        elif ch==4:
            price=db['stationary']['books']['class IX']['price']
            qt=int(input('How many sets you required: '))
            db['stationary']['books']['class IX']['stock']-=qt
            print(f'You purchase {qt} quantity of book')
            l.append(f'Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}')
            db.close()
            stationary()
        elif ch==5:
            price=db['stationary']['books']['class X']['price']
            qt=int(input('How many sets you required: '))
            db['stationary']['books']['class X']['stock']-=qt
            print(f'You purchase {qt} quantity of book')
            l.append(f'Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}')
            db.close()
            stationary()
        else:
            print('Please select valid class')
            stationary()
    else:
        main()
        
        
def electronics():
    db=shelve.open('supermarket.db',writeback=True)
    count=1
    for i in db['electronics']:
        print(f'{count}.{i}')
        count+=1
    print(f'{count}.main')
    ch=int(input('Select an item from above:'))
    if ch==1:
        s='''1.OnePlus\n2.Iphone\n3.MI'''
        print(s)
        ch=int(input('Select Brand:'))
        if ch==1:
            print(f"Availible Models:{db['electronics']['mobile']['brand']['one plus']['model']}")
            print(f"Prices          :{db['electronics']['mobile']['brand']['one plus']['price']}")
            model=input('Enter Model:')
            try:
                index1=db['electronics']['mobile']['brand']['one plus']['model'].index(model)
                price=db['electronics']['mobile']['brand']['one plus']['price'][index1]
                qt=int(input('Enter Quantity Required:'))
                db['electronics']['mobile']['brand']['one plus']['stock'][index1]-=qt
                l.append(f'ELECTRONICS\tMOBILE\tOnePlus\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} One Plus {model} mobile.')
                electronics()
            except:
                print('Please Select a valid Option.')
                electronics()
        elif ch==2:
            print(f"Availible Models:{db['electronics']['mobile']['brand']['iphone']['model']}")
            print(f"Prices          :{db['electronics']['mobile']['brand']['iphone']['price']}")
            model=input('Enter Model:')
            try:
                index1=db['electronics']['mobile']['brand']['iphone']['model'].index(model)
                price=db['electronics']['mobile']['brand']['iphone']['price'][index1]
                qt=int(input('Enter Quantity Required:'))
                db['electronics']['mobile']['brand']['iphone']['stock'][index1]-=qt
                l.append(f'ELECTRONICS\tMOBILE\tIPHONE\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Iphone {model} mobile.')
                electronics()
            except:
                print('Please Select a valid Option.')
                electronics()
        elif ch==3:
            print(f"Availible Models:{db['electronics']['mobile']['brand']['MI']['model']}")
            print(f"Prices          :{db['electronics']['mobile']['brand']['MI']['price']}")
            model=input('Enter Model No.:')
            try:
                index1=db['electronics']['mobile']['brand']['MI']['model'].index(model)
                price=db['electronics']['mobile']['brand']['MI']['price'][index1]
                qt=int(input('Enter Quantity Required:'))
                db['electronics']['mobile']['brand']['MI']['stock'][index1]-=qt
                l.append(f'ELECTRONICS\tMOBILE\tMI\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} MI {model} mobile.')
                electronics()
            except:
                print('Please Select a valid Option.')
                electronics()
        else:
            print('Please Select a valid Option.')
            electronics()
    elif ch==2:
        s='''1.hp\n2.Samsung\n3.Dell'''
        print(s)
        ch=int(input('Select Brand:'))
        if ch==1:
            print(f"Availible Models:{db['electronics']['laptop']['brand']['hp']['model']}")
            print(f"Prices          :{db['electronics']['laptop']['brand']['hp']['price']}")
            model=input('Enter Model No.:')
            try:
                index1=db['electronics']['laptop']['brand']['hp']['model'].index(model)
                price=db['electronics']['laptop']['brand']['hp']['price'][index1]
                qt=int(input('Enter Quantity Required:'))
                db['electronics']['laptop']['brand']['hp']['stock'][index1]-=qt
                l.append(f'ELECTRONICS\tLAPTOP\tHP\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} {model} Laptop.')
                electronics()
            except:
                print('Please Select a valid Option.')
                electronics()
        elif ch==2:
            print(f"Availible Models:{db['electronics']['laptop']['brand']['samsung']['model']}")
            print(f"Prices          :{db['electronics']['laptop']['brand']['samsung']['price']}")
            model=input('Enter Model No.:')
            try:
                index1=db['electronics']['laptop']['brand']['samsung']['model'].index(model)
                price=db['electronics']['laptop']['brand']['samsung']['price'][index1]
                qt=int(input('Enter Quantity Required:'))
                db['electronics']['laptop']['brand']['samsung']['stock'][index1]-=qt
                l.append(f'ELECTRONICS\tLAPTOP\tSAMSUNG\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} {model} Laptop.')
                electronics()
            except:
                print('Please Select a valid Option.')
                electronics()
        elif ch==3:
            print(f"Availible Models:{db['electronics']['laptop']['brand']['dell']['model']}")
            print(f"Prices          :{db['electronics']['laptop']['brand']['dell']['price']}")
            model=input('Enter Model No.:')
            try:
                index1=db['electronics']['laptop']['brand']['dell']['model'].index(model)
                price=db['electronics']['laptop']['brand']['dell']['price'][index1]
                qt=int(input('Enter Quantity Required:'))
                db['electronics']['laptop']['brand']['dell']['stock'][index1]-=qt
                l.append(f'ELECTRONICS\tLAPTOP\tDELL\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} {model} Laptop.')
                electronics()
            except:
                print('Please Select a valid Option.')
                electronics()
        else:
            print('Please Select a valid Option.')
            electronics()
    else:
        main()
        
        
def cosmetics():
    db=shelve.open('supermarket.db',writeback=True)
    count=1
    for i in db['cosmetics']:
        print(f"{count}.{i}")
        count+=1
    print(f"{count}.main")
    ch=int(input('Select Item from Above: '))
    if ch==1:
        s='''1.Joy\n2.Vaseline'''
        print(s)
        ch=int(input('Select a Brand:'))
        if ch==1:
            print('Availible Prices:',db['cosmetics']['bodylotion']['brand']['joy']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['bodylotion']['brand']['joy']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['bodylotion']['brand']['joy']['stock'][index1]-=qt
                l.append(f'COSMETICS\tBODYLOTION\tJOY\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Joy Bodylotions.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
        elif ch==2:
            print('Availible Prices:',db['cosmetics']['bodylotion']['brand']['vaseline']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['bodylotion']['brand']['vaseline']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['bodylotion']['brand']['vaseline']['stock'][index1]-=qt
                l.append(f'COSMETICS\tBODYLOTION\tVASELINE\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Vaseline Bodylotions.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
        else:
            print('Please Select a valid Option.')
            cosmetics()
    elif ch==2:
        s='''1.Lifeboy\n2.Dettol\n3.Godrej No.1'''
        print(s)
        ch=int(input('Select a Brand:'))
        if ch==1:
            print('Availible Prices:',db['cosmetics']['soap']['brand']['lifeboy']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['soap']['brand']['lifeboy']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['soap']['brand']['lifeboy']['stock'][index1]-=qt
                l.append(f'COSMETICS\tSOAP\tLIFEBOY\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Lifeboy Soaps.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
        elif ch==2:
            print('Availible Prices:',db['cosmetics']['soap']['brand']['dettol']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['soap']['brand']['dettol']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['soap']['brand']['dettol']['stock'][index1]-=qt
                l.append(f'COSMETICS\tSOAP\tDETTOL\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Dettol Soaps.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
        elif ch==3:
            print('Availible Prices:',db['cosmetics']['soap']['brand']['godrej no.1 ']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['soap']['brand']['godrej no.1 ']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['soap']['brand']['godrej no.1 ']['stock'][index1]-=qt
                l.append(f'COSMETICS\tSOAP\tGODREJ NO.1\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Godrej No.1  Soaps.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
        else:
            print('Please Select a valid Option.')
            cosmetics()
    elif ch==3:
        s='''1.Boroplus\n2.Fair Handsome\n3.Meglow'''
        print(s)
        ch=int(input('Select a Brand:'))
        if ch==1:
            print('Availible Prices:',db['cosmetics']['cream']['brand']['boroplus']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['cream']['brand']['boroplus']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['cream']['brand']['boroplus']['stock'][index1]-=qt
                l.append(f'COSMETICS\tCREAM\tBOROPLUS\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Boroplus Creams.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
        elif ch==2:
            print('Availible Prices:',db['cosmetics']['cream']['brand']['fair Handsome']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['cream']['brand']['fair Handsome']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['cream']['brand']['fair Handsome']['stock'][index1]-=qt
                l.append(f'COSMETICS\tCREAM\tFAIR HANDSOME\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Fair Handsome creams.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
        elif ch==3:
            print('Availible Prices:',db['cosmetics']['cream']['brand']['meglow']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['cream']['brand']['meglow']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['cream']['brand']['meglow']['stock'][index1]-=qt
                l.append(f'COSMETICS\tCREAM\tMEGLOW\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Meglow creams.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
        else:
            print('Please Select a valid Option.')
            cosmetics()
    elif ch==4:
        s='''1.Denver\n2.Park Avenue\n3.Fogg'''
        print(s)
        ch=int(input('Select a Brand:'))
        if ch==1:
            print('Availible Prices:',db['cosmetics']['perfume']['brand']['denver']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['perfume']['brand']['denver']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['perfume']['brand']['denver']['stock'][index1]-=qt
                l.append(f'COSMETICS\tPERFUME\tDENVER\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Denver Perfumes.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()

        elif ch==2:
            print('Availible Prices:',db['cosmetics']['perfume']['brand']['park avenue']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['perfume']['brand']['park avenue']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['perfume']['brand']['park avenue']['stock'][index1]-=qt
                l.append(f'COSMETICS\tPERFUME\tPARK AVENUE\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Park Avenue Perfumes.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
        elif ch==3:
            print('Availible Prices:',db['cosmetics']['perfume']['brand']['fogg']['price'])
            price=int(input('Please Select from the above given prices:'))
            try:
                index1=db['cosmetics']['perfume']['brand']['fogg']['price'].index(price)
                qt=int(input('Enter Quantity Required:'))
                db['cosmetics']['perfume']['brand']['fogg']['stock'][index1]-=qt
                l.append(f'COSMETICS\tPERFUME\tFOGG\t{qt}\tRs.{price}\t{qt*price}')
                db.close()
                print(f'You purchased {qt} Fogg Perfumes.')
                cosmetics()
            except:
                print('Please Select a valid Option.')
                cosmetics()
            
        else:
            print('Please Select a valid Option.')
            cosmetics()  
    else:
        main()
        
        
def chocolate():
    db=shelve.open('supermarket.db',writeback=True)
    count=1
    for i in db['chocolate']:
        print(f"{count}.{i}")
        count+=1
    print(f"{count}.main")
    ch=int(input('Select Item from Above: '))
    if ch==1:
        print('Availible Prices:',db['chocolate']['dairymilk']['price'])
        price=int(input('Please Select from the above given Prices:'))
        try:
            index1=db['chocolate']['dairymilk']['price'].index(price)
            qt=int(input('Enter Quantity Required:'))
            db['chocolate']['dairymilk']['stock'][index1]-=qt
            l.append(f'EATABLES\tCHOCOLATE\tDAIRYMILK\t{qt}\tRs.{price}\t{qt*price}')
            db.close()
            print(f'You purchased {qt} Dairy Milk chocolates.')
            chocolate()
        except:
            print('Please Select a valid Option.')
            chocolate()  
    elif ch==2:
        print('Availible Prices:',db['chocolate']['munch']['price'])
        price=int(input('Please Select from the above given Prices:'))
        try:
            index1=db['chocolate']['munch']['price'].index(price)
            qt=int(input('Enter Quantity Required:'))
            db['chocolate']['munch']['stock'][index1]-=qt
            l.append(f'EATABLES\tCHOCOLATE\tMUNCH\t{qt}\tRs.{price}\t{qt*price}')
            db.close()
            print(f'You purchased {qt} Munch chocolates.')
            chocolate()
        except:
            print('Please Select a valid Option.')
            chocolate()  
    elif ch==3:
        print('Availible Prices:',db['chocolate']['kit-kat']['price'])
        price=int(input('Please Select from the above given Prices:'))
        try:
            index1=db['chocolate']['kit-kat']['price'].index(price)
            qt=int(input('Enter Quantity Required:'))
            db['chocolate']['kit-kat']['stock'][index1]-=qt
            l.append(f'EATABLES\tCHOCOLATE\tKIT-KAT\t{qt}\tRs.{price}\t{qt*price}')
            db.close()
            print(f'You purchased {qt} Kit-Kat chocolates.')
            chocolate()
        except:
            print('Please Select a valid Option.')
            chocolate()  
    elif ch==4:
        print('Availible Prices:',db['chocolate']['five star']['price'])
        price=int(input('Please Select from the above given Prices:'))
        try:
            index1=db['chocolate']['five star']['price'].index(price)
            qt=int(input('Enter Quantity Required:'))
            db['chocolate']['five star']['stock'][index1]-=qt
            l.append(f'EATABLES\tCHOCOLATE\tFIVE STAR\t{qt}\tRs.{price}\t{qt*price}')
            db.close()
            print(f'You purchased {qt} Five Star chocolates.')
            chocolate()
        except:
            print('Please Select a valid Option.')
            chocolate()  
    elif ch==5:
        print('Availible Prices:',db['chocolate']['perk']['price'])
        price=int(input('Please Select from the above given Prices:'))
        try:
            index1=db['chocolate']['perk']['price'].index(price)
            qt=int(input('Enter Quantity Required:'))
            db['chocolate']['perk']['stock'][index1]-=qt
            l.append(f'EATABLES\tCHOCOLATE\tPERK\t{qt}\tRs.{price}\t{qt*price}')
            db.close()
            print(f'You purchased {qt} Perk chocolates.')
            chocolate()
        except:
            print('Please Select a valid Option.')
            chocolate()  
    else:
        main()
main()
# Out:
# 1.Stationary
# 2.Electronics
# 3.Cosmetics
# 4.Chocolate
# 5.Exit
# Enter a number: 3
# 1.bodylotion
# 2.soap
# 3.cream
# 4.perfume
# 5.main
# Select Item from Above: 3
# 1.Boroplus
# 2.Fair Handsome
# 3.Meglow
# Select a Brand:1
# Availible Prices: [20, 40]
# Please Select from the above given prices:40
# Enter Quantity Required:1
# You purchased 1 Boroplus Creams.
# 1.bodylotion
# 2.soap
# 3.cream
# 4.perfume
# 5.main
# Select Item from Above: 4
# 1.Denver
# 2.Park Avenue
# 3.Fogg
# Select a Brand:2
# Availible Prices: [120, 180]
# Please Select from the above given prices:180
# Enter Quantity Required:1
# You purchased 1 Park Avenue Perfumes.
# 1.bodylotion
# 2.soap
# 3.cream
# 4.perfume
# 5.main
# Select Item from Above: 5
# 1.Stationary
# 2.Electronics
# 3.Cosmetics
# 4.Chocolate
# 5.Exit
# Enter a number: 2
# 1.mobile
# 2.laptop
# 3.main
# Select an item from above:2
# 1.hp
# 2.Samsung
# 3.Dell
# Select Brand:3
# ...
